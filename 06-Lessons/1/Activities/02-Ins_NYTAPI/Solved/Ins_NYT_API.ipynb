# %%
# Dependencies
import requests
from pprint import pprint
from config import api_key

url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# %%
# Search for articles that mention granola
query = "vaccine"

# %%
# Build query URL
query_url = url + "api-key=" + api_key + "&q=" + query
query_url
# Out:
# 'https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=w5DQYDfwARnJAxAUjkLKVusBxrMeGADp&q=vaccine'

# %%
# Request articles
articles = requests.get(query_url).json()

# The "response" property in articles contains the actual articles
# list comprehension.
articles_list = [article for article in articles["response"]["docs"]]
pprint(articles_list)
# Out:
# [{'_id': 'nyt://interactive/ae04e397-e2b4-5145-9576-cdff20889cd1',
#   'abstract': 'The city is ramping up a program to vaccinate people in select '
#               "subway stations as a way to boost the city's vaccination rate.",
#   'byline': {'organization': None,
#              'original': 'By Joseph Goldstein',
#              'person': [{'firstname': 'Joseph',
#                          'lastname': 'Goldstein',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 1,
#                          'role': 'reported',
#                          'title': None}]},
#   'document_type': 'multimedia',
#   'headline': {'content_kicker': None,
#                'kicker': None,
#                'main': 'What It’s Like to Be Vaccinated in a Subway Station',
#                'name': None,
#                'print_headline': None,
#                'seo': None,
#                'sub': None},
#   'keywords': [{'major': 'N', 'name': 'subject', 'rank': 1, 'value': 'Subways'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 2,
#                 'value': 'Vaccination and Immunization'},
#                {'major': 'N',
#                 'name': 'glocations',
#                 'rank': 3,
#                 'value': 'Coney Island (Brooklyn, NY)'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 4,
#                 'value': 'Stations and Terminals (Passenger)'},
#                {'major': 'N',
#                 'name': 'glocations',
#                 'rank': 5,
#                 'value': 'New York City'},
#                {'major': 'N',
#                 'name': 'organizations',
#                 'rank': 6,
#                 'value': 'Grand Central Terminal (Manhattan, NY)'},
#                {'major': 'N',
#                 'name': 'organizations',
#                 'rank': 7,
#                 'value': 'Nathans Famous Inc'}],
#   'lead_paragraph': 'The city is ramping up a program to vaccinate people in '
#                     "select subway stations as a way to boost the city's "
#                     'vaccination rate.',
#   'multimedia': [{'caption': None,
#                   'credit': None,
#                   'crop_name': 'articleLarge',
#                   'height': 338,
#                   'legacy': {'xlarge': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-articleLarge-v2.jpg',
#                              'xlargeheight': 338,
#                              'xlargewidth': 600},
#                   'rank': 0,
#                   'subType': 'xlarge',
#                   'subtype': 'xlarge',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-articleLarge-v2.jpg',
#                   'width': 600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'popup',
#                   'height': 366,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'popup',
#                   'subtype': 'popup',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-popup-v2.jpg',
#                   'width': 650},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog480',
#                   'height': 270,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog480',
#                   'subtype': 'blog480',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-blog480-v2.jpg',
#                   'width': 480},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog533',
#                   'height': 300,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog533',
#                   'subtype': 'blog533',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-blog533-v2.jpg',
#                   'width': 533},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog427',
#                   'height': 240,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog427',
#                   'subtype': 'blog427',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-blog427-v2.jpg',
#                   'width': 427},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'tmagSF',
#                   'height': 204,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'tmagSF',
#                   'subtype': 'tmagSF',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-tmagSF-v2.jpg',
#                   'width': 362},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'tmagArticle',
#                   'height': 333,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'tmagArticle',
#                   'subtype': 'tmagArticle',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-tmagArticle-v2.jpg',
#                   'width': 592},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'slide',
#                   'height': 338,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'slide',
#                   'subtype': 'slide',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-slide-v2.jpg',
#                   'width': 600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'jumbo',
#                   'height': 576,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'jumbo',
#                   'subtype': 'jumbo',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-jumbo-v2.jpg',
#                   'width': 1024},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'superJumbo',
#                   'height': 1152,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'superJumbo',
#                   'subtype': 'superJumbo',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-superJumbo-v2.jpg',
#                   'width': 2048},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog225',
#                   'height': 127,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog225',
#                   'subtype': 'blog225',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-blog225-v2.jpg',
#                   'width': 225},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master1050',
#                   'height': 591,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master1050',
#                   'subtype': 'master1050',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-master1050-v2.jpg',
#                   'width': 1050},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master675',
#                   'height': 380,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master675',
#                   'subtype': 'master675',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-master675-v2.jpg',
#                   'width': 675},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master495',
#                   'height': 278,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master495',
#                   'subtype': 'master495',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-master495-v2.jpg',
#                   'width': 495},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master180',
#                   'height': 101,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master180',
#                   'subtype': 'master180',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-master180-v2.jpg',
#                   'width': 180},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master315',
#                   'height': 177,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master315',
#                   'subtype': 'master315',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-master315-v2.jpg',
#                   'width': 315},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master768',
#                   'height': 432,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master768',
#                   'subtype': 'master768',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-master768-v2.jpg',
#                   'width': 768},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'thumbStandard',
#                   'height': 75,
#                   'legacy': {'thumbnail': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-thumbStandard-v2.jpg',
#                              'thumbnailheight': 75,
#                              'thumbnailwidth': 75},
#                   'rank': 0,
#                   'subType': 'thumbnail',
#                   'subtype': 'thumbnail',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-thumbStandard-v2.jpg',
#                   'width': 75},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blogSmallThumb',
#                   'height': 50,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blogSmallThumb',
#                   'subtype': 'blogSmallThumb',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-blogSmallThumb-v2.jpg',
#                   'width': 50},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'thumbLarge',
#                   'height': 150,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'thumbLarge',
#                   'subtype': 'thumbLarge',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-thumbLarge-v2.jpg',
#                   'width': 150},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'smallSquare168',
#                   'height': 168,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'smallSquare168',
#                   'subtype': 'smallSquare168',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-smallSquare168-v2.jpg',
#                   'width': 168},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'smallSquare252',
#                   'height': 252,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'smallSquare252',
#                   'subtype': 'smallSquare252',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-smallSquare252-v2.jpg',
#                   'width': 252},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'square320',
#                   'height': 320,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'square320',
#                   'subtype': 'square320',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-square320.jpg',
#                   'width': 320},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'moth',
#                   'height': 151,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'moth',
#                   'subtype': 'moth',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-moth.jpg',
#                   'width': 151},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'filmstrip',
#                   'height': 190,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'filmstrip',
#                   'subtype': 'filmstrip',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-filmstrip.jpg',
#                   'width': 190},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'square640',
#                   'height': 640,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'square640',
#                   'subtype': 'square640',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-square640.jpg',
#                   'width': 640},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumSquare149',
#                   'height': 149,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumSquare149',
#                   'subtype': 'mediumSquare149',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-mediumSquare149.jpg',
#                   'width': 149},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumSquareAt3X',
#                   'height': 1801,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumSquareAt3X',
#                   'subtype': 'mediumSquareAt3X',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-mediumSquareAt3X.jpg',
#                   'width': 1800},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'sfSpan',
#                   'height': 263,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'sfSpan',
#                   'subtype': 'sfSpan',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-sfSpan-v2.jpg',
#                   'width': 395},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'largeHorizontal375',
#                   'height': 250,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'largeHorizontal375',
#                   'subtype': 'largeHorizontal375',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-largeHorizontal375-v2.jpg',
#                   'width': 375},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'largeHorizontalJumbo',
#                   'height': 683,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'largeHorizontalJumbo',
#                   'subtype': 'largeHorizontalJumbo',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-largeHorizontalJumbo-v2.jpg',
#                   'width': 1024},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'horizontalMediumAt2X',
#                   'height': 3001,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'horizontalMediumAt2X',
#                   'subtype': 'horizontalMediumAt2X',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-horizontalMediumAt2X-v2.jpg',
#                   'width': 4501},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'hpLarge',
#                   'height': 287,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'hpLarge',
#                   'subtype': 'hpLarge',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-hpLarge-v2.jpg',
#                   'width': 511},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'largeWidescreen573',
#                   'height': 322,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'largeWidescreen573',
#                   'subtype': 'largeWidescreen573',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-largeWidescreen573-v2.jpg',
#                   'width': 573},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'largeWidescreen1050',
#                   'height': 591,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'largeWidescreen1050',
#                   'subtype': 'largeWidescreen1050',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-largeWidescreen1050-v2.jpg',
#                   'width': 1050},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'thumbWide',
#                   'height': 126,
#                   'legacy': {'wide': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-thumbWide-v2.jpg',
#                              'wideheight': 126,
#                              'widewidth': 190},
#                   'rank': 0,
#                   'subType': 'wide',
#                   'subtype': 'wide',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-thumbWide-v2.jpg',
#                   'width': 190},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoThumb',
#                   'height': 50,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoThumb',
#                   'subtype': 'videoThumb',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-videoThumb-v2.jpg',
#                   'width': 75},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoLarge',
#                   'height': 507,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoLarge',
#                   'subtype': 'videoLarge',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-videoLarge-v2.jpg',
#                   'width': 768},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumThreeByTwo210',
#                   'height': 140,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumThreeByTwo210',
#                   'subtype': 'mediumThreeByTwo210',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-mediumThreeByTwo210-v2.jpg',
#                   'width': 210},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumThreeByTwo225',
#                   'height': 150,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumThreeByTwo225',
#                   'subtype': 'mediumThreeByTwo225',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-mediumThreeByTwo225-v2.jpg',
#                   'width': 225},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumThreeByTwo440',
#                   'height': 293,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumThreeByTwo440',
#                   'subtype': 'mediumThreeByTwo440',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-mediumThreeByTwo440-v2.jpg',
#                   'width': 440},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumThreeByTwo252',
#                   'height': 168,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumThreeByTwo252',
#                   'subtype': 'mediumThreeByTwo252',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-mediumThreeByTwo252-v2.jpg',
#                   'width': 252},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumThreeByTwo378',
#                   'height': 252,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumThreeByTwo378',
#                   'subtype': 'mediumThreeByTwo378',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-mediumThreeByTwo378-v2.jpg',
#                   'width': 378},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'threeByTwoLargeAt2X',
#                   'height': 3001,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'threeByTwoLargeAt2X',
#                   'subtype': 'threeByTwoLargeAt2X',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-threeByTwoLargeAt2X-v2.jpg',
#                   'width': 4501},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'threeByTwoMediumAt2X',
#                   'height': 1000,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'threeByTwoMediumAt2X',
#                   'subtype': 'threeByTwoMediumAt2X',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-threeByTwoMediumAt2X-v2.jpg',
#                   'width': 1500},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'threeByTwoSmallAt2X',
#                   'height': 400,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'threeByTwoSmallAt2X',
#                   'subtype': 'threeByTwoSmallAt2X',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-threeByTwoSmallAt2X-v2.jpg',
#                   'width': 600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'articleInline',
#                   'height': 107,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'articleInline',
#                   'subtype': 'articleInline',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-articleInline-v2.jpg',
#                   'width': 190},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'hpSmall',
#                   'height': 92,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'hpSmall',
#                   'subtype': 'hpSmall',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-hpSmall-v2.jpg',
#                   'width': 163},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blogSmallInline',
#                   'height': 85,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blogSmallInline',
#                   'subtype': 'blogSmallInline',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-blogSmallInline-v2.jpg',
#                   'width': 151},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumFlexible177',
#                   'height': 100,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumFlexible177',
#                   'subtype': 'mediumFlexible177',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-mediumFlexible177-v2.jpg',
#                   'width': 177},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSmall',
#                   'height': 281,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSmall',
#                   'subtype': 'videoSmall',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-videoSmall-v2.jpg',
#                   'width': 500},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoHpMedium',
#                   'height': 211,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoHpMedium',
#                   'subtype': 'videoHpMedium',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-videoHpMedium-v2.jpg',
#                   'width': 375},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine600',
#                   'height': 338,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine600',
#                   'subtype': 'videoSixteenByNine600',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-videoSixteenByNine600-v2.jpg',
#                   'width': 600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine540',
#                   'height': 304,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine540',
#                   'subtype': 'videoSixteenByNine540',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-videoSixteenByNine540-v2.jpg',
#                   'width': 540},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine495',
#                   'height': 278,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine495',
#                   'subtype': 'videoSixteenByNine495',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-videoSixteenByNine495-v2.jpg',
#                   'width': 495},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine390',
#                   'height': 219,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine390',
#                   'subtype': 'videoSixteenByNine390',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-videoSixteenByNine390-v2.jpg',
#                   'width': 390},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine1050',
#                   'height': 591,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine1050',
#                   'subtype': 'videoSixteenByNine1050',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-videoSixteenByNine1050-v2.jpg',
#                   'width': 1050},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine480',
#                   'height': 270,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine480',
#                   'subtype': 'videoSixteenByNine480',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-videoSixteenByNine480-v2.jpg',
#                   'width': 480},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine310',
#                   'height': 174,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine310',
#                   'subtype': 'videoSixteenByNine310',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-videoSixteenByNine310-v2.jpg',
#                   'width': 310},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine225',
#                   'height': 126,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine225',
#                   'subtype': 'videoSixteenByNine225',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-videoSixteenByNine225-v2.jpg',
#                   'width': 225},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine96',
#                   'height': 54,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine96',
#                   'subtype': 'videoSixteenByNine96',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-videoSixteenByNine96-v2.jpg',
#                   'width': 96},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine3000',
#                   'height': 1688,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine3000',
#                   'subtype': 'videoSixteenByNine3000',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-videoSixteenByNine3000-v2.jpg',
#                   'width': 3000},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine768',
#                   'height': 432,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine768',
#                   'subtype': 'videoSixteenByNine768',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-videoSixteenByNine768-v2.jpg',
#                   'width': 768},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine150',
#                   'height': 84,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine150',
#                   'subtype': 'videoSixteenByNine150',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-videoSixteenByNine150-v2.jpg',
#                   'width': 150},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNineJumbo1600',
#                   'height': 900,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNineJumbo1600',
#                   'subtype': 'videoSixteenByNineJumbo1600',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-videoSixteenByNineJumbo1600-v2.jpg',
#                   'width': 1600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'miniMoth',
#                   'height': 70,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'miniMoth',
#                   'subtype': 'miniMoth',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-miniMoth-v2.jpg',
#                   'width': 151},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'windowsTile336H',
#                   'height': 336,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'windowsTile336H',
#                   'subtype': 'windowsTile336H',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-windowsTile336H-v2.jpg',
#                   'width': 694},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoFifteenBySeven1305',
#                   'height': 609,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoFifteenBySeven1305',
#                   'subtype': 'videoFifteenBySeven1305',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-videoFifteenBySeven1305-v2.jpg',
#                   'width': 1305},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoFifteenBySeven2610',
#                   'height': 1218,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoFifteenBySeven2610',
#                   'subtype': 'videoFifteenBySeven2610',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-videoFifteenBySeven2610-v2.jpg',
#                   'width': 2610},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'facebookJumbo',
#                   'height': 550,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'facebookJumbo',
#                   'subtype': 'facebookJumbo',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-facebookJumbo-v2.jpg',
#                   'width': 1050},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'watch308',
#                   'height': 348,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'watch308',
#                   'subtype': 'watch308',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-watch308-v2.jpg',
#                   'width': 312},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'watch268',
#                   'height': 303,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'watch268',
#                   'subtype': 'watch268',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-watch268-v2.jpg',
#                   'width': 272},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'verticalTwoByThree735',
#                   'height': 1102,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'verticalTwoByThree735',
#                   'subtype': 'verticalTwoByThree735',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-verticalTwoByThree735-v2.jpg',
#                   'width': 735},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mobileMasterAt3x',
#                   'height': 1013,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mobileMasterAt3x',
#                   'subtype': 'mobileMasterAt3x',
#                   'type': 'image',
#                   'url': 'images/2021/05/20/nyregion/20vaccine-burst3/20vaccine-burst3-mobileMasterAt3x-v2.jpg',
#                   'width': 1800}],
#   'news_desk': 'New York',
#   'pub_date': '2021-05-20T18:24:36+0000',
#   'section_name': 'New York',
#   'snippet': 'The city is ramping up a program to vaccinate people in select '
#              "subway stations as a way to boost the city's vaccination rate.",
#   'source': 'The New York Times',
#   'type_of_material': 'Interactive Feature',
#   'uri': 'nyt://interactive/ae04e397-e2b4-5145-9576-cdff20889cd1',
#   'web_url': 'https://www.nytimes.com/interactive/2021/05/20/nyregion/nyvaccine-subway.html',
#   'word_count': 0},
#  {'_id': 'nyt://article/bc0403f8-d21e-5cee-a5ae-5842bb2b5ad0',
#   'abstract': 'And the fear of losing control.',
#   'byline': {'organization': None,
#              'original': 'By Lauren Jackson and Mahima Chablani',
#              'person': [{'firstname': 'Lauren',
#                          'lastname': 'Jackson',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 1,
#                          'role': 'reported',
#                          'title': None},
#                         {'firstname': 'Mahima',
#                          'lastname': 'Chablani',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 2,
#                          'role': 'reported',
#                          'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': None,
#                'kicker': 'The Daily Newsletter',
#                'main': 'Vaccine Hesitancy in Rural Tennessee',
#                'name': None,
#                'print_headline': 'Conversations With Vaccine Skeptics',
#                'seo': None,
#                'sub': None},
#   'keywords': [{'major': 'N',
#                 'name': 'glocations',
#                 'rank': 1,
#                 'value': 'Tennessee'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 2,
#                 'value': 'Coronavirus (2019-nCoV)'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 3,
#                 'value': 'Vaccination and Immunization'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 4,
#                 'value': 'Religion and Belief'}],
#   'lead_paragraph': 'Hi everyone, happy Friday. Our team has been busy this '
#                     'week, covering the news from Silicon Valley to Jerusalem. '
#                     'On Fridays, we take some time to plan our week ahead. So '
#                     'we’d love to know: What would you like to hear an episode '
#                     'about in the coming days? Let us know here — we always '
#                     'love to hear what is on your mind.',
#   'multimedia': [{'caption': None,
#                   'credit': None,
#                   'crop_name': 'articleLarge',
#                   'height': 400,
#                   'legacy': {'xlarge': 'images/2021/04/21/science/14daily-newsletter-1/merlin_186278148_b4887446-19fb-4d06-b529-7a83bcbb55a3-articleLarge.jpg',
#                              'xlargeheight': 400,
#                              'xlargewidth': 600},
#                   'rank': 0,
#                   'subType': 'xlarge',
#                   'subtype': 'xlarge',
#                   'type': 'image',
#                   'url': 'images/2021/04/21/science/14daily-newsletter-1/merlin_186278148_b4887446-19fb-4d06-b529-7a83bcbb55a3-articleLarge.jpg',
#                   'width': 600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'popup',
#                   'height': 433,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'popup',
#                   'subtype': 'popup',
#                   'type': 'image',
#                   'url': 'images/2021/04/21/science/14daily-newsletter-1/merlin_186278148_b4887446-19fb-4d06-b529-7a83bcbb55a3-popup.jpg',
#                   'width': 650},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog480',
#                   'height': 320,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog480',
#                   'subtype': 'blog480',
#                   'type': 'image',
#                   'url': 'images/2021/04/21/science/14daily-newsletter-1/merlin_186278148_b4887446-19fb-4d06-b529-7a83bcbb55a3-blog480.jpg',
#                   'width': 480},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog533',
#                   'height': 355,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog533',
#                   'subtype': 'blog533',
#                   'type': 'image',
#                   'url': 'images/2021/04/21/science/14daily-newsletter-1/merlin_186278148_b4887446-19fb-4d06-b529-7a83bcbb55a3-blog533.jpg',
#                   'width': 533},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog427',
#                   'height': 285,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog427',
#                   'subtype': 'blog427',
#                   'type': 'image',
#                   'url': 'images/2021/04/21/science/14daily-newsletter-1/merlin_186278148_b4887446-19fb-4d06-b529-7a83bcbb55a3-blog427.jpg',
#                   'width': 427},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'tmagSF',
#                   'height': 241,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'tmagSF',
#                   'subtype': 'tmagSF',
#                   'type': 'image',
#                   'url': 'images/2021/04/21/science/14daily-newsletter-1/merlin_186278148_b4887446-19fb-4d06-b529-7a83bcbb55a3-tmagSF.jpg',
#                   'width': 362},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'tmagArticle',
#                   'height': 395,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'tmagArticle',
#                   'subtype': 'tmagArticle',
#                   'type': 'image',
#                   'url': 'images/2021/04/21/science/14daily-newsletter-1/merlin_186278148_b4887446-19fb-4d06-b529-7a83bcbb55a3-tmagArticle.jpg',
#                   'width': 592},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'slide',
#                   'height': 400,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'slide',
#                   'subtype': 'slide',
#                   'type': 'image',
#                   'url': 'images/2021/04/21/science/14daily-newsletter-1/merlin_186278148_b4887446-19fb-4d06-b529-7a83bcbb55a3-slide.jpg',
#                   'width': 600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'jumbo',
#                   'height': 683,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'jumbo',
#                   'subtype': 'jumbo',
#                   'type': 'image',
#                   'url': 'images/2021/04/21/science/14daily-newsletter-1/merlin_186278148_b4887446-19fb-4d06-b529-7a83bcbb55a3-jumbo.jpg',
#                   'width': 1024},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'superJumbo',
#                   'height': 1365,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'superJumbo',
#                   'subtype': 'superJumbo',
#                   'type': 'image',
#                   'url': 'images/2021/04/21/science/14daily-newsletter-1/merlin_186278148_b4887446-19fb-4d06-b529-7a83bcbb55a3-superJumbo.jpg',
#                   'width': 2048},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog225',
#                   'height': 150,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog225',
#                   'subtype': 'blog225',
#                   'type': 'image',
#                   'url': 'images/2021/04/21/science/14daily-newsletter-1/merlin_186278148_b4887446-19fb-4d06-b529-7a83bcbb55a3-blog225.jpg',
#                   'width': 225},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master1050',
#                   'height': 700,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master1050',
#                   'subtype': 'master1050',
#                   'type': 'image',
#                   'url': 'images/2021/04/21/science/14daily-newsletter-1/merlin_186278148_b4887446-19fb-4d06-b529-7a83bcbb55a3-master1050.jpg',
#                   'width': 1050},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master675',
#                   'height': 450,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master675',
#                   'subtype': 'master675',
#                   'type': 'image',
# ...
#                   'width': 5264},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'threeByTwoMediumAt2X',
#                   'height': 999,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'threeByTwoMediumAt2X',
#                   'subtype': 'threeByTwoMediumAt2X',
#                   'type': 'image',
#                   'url': 'images/2021/05/11/multimedia/00xp-vaxsites-dracula/00xp-vaxsites-dracula-threeByTwoMediumAt2X.jpg',
#                   'width': 1500},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'threeByTwoSmallAt2X',
#                   'height': 400,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'threeByTwoSmallAt2X',
#                   'subtype': 'threeByTwoSmallAt2X',
#                   'type': 'image',
#                   'url': 'images/2021/05/11/multimedia/00xp-vaxsites-dracula/00xp-vaxsites-dracula-threeByTwoSmallAt2X.jpg',
#                   'width': 600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'articleInline',
#                   'height': 131,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'articleInline',
#                   'subtype': 'articleInline',
#                   'type': 'image',
#                   'url': 'images/2021/05/11/multimedia/00xp-vaxsites-dracula/merlin_187494546_507cbe65-090e-44fa-811a-2371403e33ad-articleInline.jpg',
#                   'width': 190},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'hpSmall',
#                   'height': 112,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'hpSmall',
#                   'subtype': 'hpSmall',
#                   'type': 'image',
#                   'url': 'images/2021/05/11/multimedia/00xp-vaxsites-dracula/merlin_187494546_507cbe65-090e-44fa-811a-2371403e33ad-hpSmall.jpg',
#                   'width': 163},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blogSmallInline',
#                   'height': 104,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blogSmallInline',
#                   'subtype': 'blogSmallInline',
#                   'type': 'image',
#                   'url': 'images/2021/05/11/multimedia/00xp-vaxsites-dracula/merlin_187494546_507cbe65-090e-44fa-811a-2371403e33ad-blogSmallInline.jpg',
#                   'width': 151},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumFlexible177',
#                   'height': 122,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumFlexible177',
#                   'subtype': 'mediumFlexible177',
#                   'type': 'image',
#                   'url': 'images/2021/05/11/multimedia/00xp-vaxsites-dracula/merlin_187494546_507cbe65-090e-44fa-811a-2371403e33ad-mediumFlexible177.jpg',
#                   'width': 177},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSmall',
#                   'height': 281,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSmall',
#                   'subtype': 'videoSmall',
#                   'type': 'image',
#                   'url': 'images/2021/05/11/multimedia/00xp-vaxsites-dracula/00xp-vaxsites-dracula-videoSmall.jpg',
#                   'width': 500},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoHpMedium',
#                   'height': 211,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoHpMedium',
#                   'subtype': 'videoHpMedium',
#                   'type': 'image',
#                   'url': 'images/2021/05/11/multimedia/00xp-vaxsites-dracula/00xp-vaxsites-dracula-videoHpMedium.jpg',
#                   'width': 375},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine600',
#                   'height': 338,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine600',
#                   'subtype': 'videoSixteenByNine600',
#                   'type': 'image',
#                   'url': 'images/2021/05/11/multimedia/00xp-vaxsites-dracula/00xp-vaxsites-dracula-videoSixteenByNine600.jpg',
#                   'width': 600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine540',
#                   'height': 304,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine540',
#                   'subtype': 'videoSixteenByNine540',
#                   'type': 'image',
#                   'url': 'images/2021/05/11/multimedia/00xp-vaxsites-dracula/00xp-vaxsites-dracula-videoSixteenByNine540.jpg',
#                   'width': 540},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine495',
#                   'height': 278,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine495',
#                   'subtype': 'videoSixteenByNine495',
#                   'type': 'image',
#                   'url': 'images/2021/05/11/multimedia/00xp-vaxsites-dracula/00xp-vaxsites-dracula-videoSixteenByNine495.jpg',
#                   'width': 495},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine390',
#                   'height': 219,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine390',
#                   'subtype': 'videoSixteenByNine390',
#                   'type': 'image',
#                   'url': 'images/2021/05/11/multimedia/00xp-vaxsites-dracula/00xp-vaxsites-dracula-videoSixteenByNine390.jpg',
#                   'width': 390},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine1050',
#                   'height': 591,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine1050',
#                   'subtype': 'videoSixteenByNine1050',
#                   'type': 'image',
#                   'url': 'images/2021/05/11/multimedia/00xp-vaxsites-dracula/00xp-vaxsites-dracula-videoSixteenByNine1050.jpg',
#                   'width': 1050},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine480',
#                   'height': 270,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine480',
#                   'subtype': 'videoSixteenByNine480',
#                   'type': 'image',
#                   'url': 'images/2021/05/11/multimedia/00xp-vaxsites-dracula/00xp-vaxsites-dracula-videoSixteenByNine480.jpg',
#                   'width': 480},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine310',
#                   'height': 174,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine310',
#                   'subtype': 'videoSixteenByNine310',
#                   'type': 'image',
#                   'url': 'images/2021/05/11/multimedia/00xp-vaxsites-dracula/00xp-vaxsites-dracula-videoSixteenByNine310.jpg',
#                   'width': 310},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine225',
#                   'height': 126,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine225',
#                   'subtype': 'videoSixteenByNine225',
#                   'type': 'image',
#                   'url': 'images/2021/05/11/multimedia/00xp-vaxsites-dracula/00xp-vaxsites-dracula-videoSixteenByNine225.jpg',
#                   'width': 225},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine96',
#                   'height': 54,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine96',
#                   'subtype': 'videoSixteenByNine96',
#                   'type': 'image',
#                   'url': 'images/2021/05/11/multimedia/00xp-vaxsites-dracula/00xp-vaxsites-dracula-videoSixteenByNine96.jpg',
#                   'width': 96},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine3000',
#                   'height': 1686,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine3000',
#                   'subtype': 'videoSixteenByNine3000',
#                   'type': 'image',
#                   'url': 'images/2021/05/11/multimedia/00xp-vaxsites-dracula/00xp-vaxsites-dracula-videoSixteenByNine3000.jpg',
#                   'width': 3000},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine768',
#                   'height': 432,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine768',
#                   'subtype': 'videoSixteenByNine768',
#                   'type': 'image',
#                   'url': 'images/2021/05/11/multimedia/00xp-vaxsites-dracula/00xp-vaxsites-dracula-videoSixteenByNine768.jpg',
#                   'width': 768},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine150',
#                   'height': 84,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine150',
#                   'subtype': 'videoSixteenByNine150',
#                   'type': 'image',
#                   'url': 'images/2021/05/11/multimedia/00xp-vaxsites-dracula/00xp-vaxsites-dracula-videoSixteenByNine150.jpg',
#                   'width': 150},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNineJumbo1600',
#                   'height': 899,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNineJumbo1600',
#                   'subtype': 'videoSixteenByNineJumbo1600',
#                   'type': 'image',
#                   'url': 'images/2021/05/11/multimedia/00xp-vaxsites-dracula/00xp-vaxsites-dracula-videoSixteenByNineJumbo1600.jpg',
#                   'width': 1600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'miniMoth',
#                   'height': 70,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'miniMoth',
#                   'subtype': 'miniMoth',
#                   'type': 'image',
#                   'url': 'images/2021/05/11/multimedia/00xp-vaxsites-dracula/00xp-vaxsites-dracula-miniMoth.jpg',
#                   'width': 151},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'windowsTile336H',
#                   'height': 336,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'windowsTile336H',
#                   'subtype': 'windowsTile336H',
#                   'type': 'image',
#                   'url': 'images/2021/05/11/multimedia/00xp-vaxsites-dracula/00xp-vaxsites-dracula-windowsTile336H.jpg',
#                   'width': 694},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoFifteenBySeven1305',
#                   'height': 609,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoFifteenBySeven1305',
#                   'subtype': 'videoFifteenBySeven1305',
#                   'type': 'image',
#                   'url': 'images/2021/05/11/multimedia/00xp-vaxsites-dracula/00xp-vaxsites-dracula-videoFifteenBySeven1305.jpg',
#                   'width': 1305},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoFifteenBySeven2610',
#                   'height': 1218,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoFifteenBySeven2610',
#                   'subtype': 'videoFifteenBySeven2610',
#                   'type': 'image',
#                   'url': 'images/2021/05/11/multimedia/00xp-vaxsites-dracula/00xp-vaxsites-dracula-videoFifteenBySeven2610.jpg',
#                   'width': 2610},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'facebookJumbo',
#                   'height': 549,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'facebookJumbo',
#                   'subtype': 'facebookJumbo',
#                   'type': 'image',
#                   'url': 'images/2021/05/11/multimedia/00xp-vaxsites-dracula/00xp-vaxsites-dracula-facebookJumbo.jpg',
#                   'width': 1050},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'watch308',
#                   'height': 348,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'watch308',
#                   'subtype': 'watch308',
#                   'type': 'image',
#                   'url': 'images/2021/05/11/multimedia/00xp-vaxsites-dracula/00xp-vaxsites-dracula-watch308.jpg',
#                   'width': 312},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'watch268',
#                   'height': 303,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'watch268',
#                   'subtype': 'watch268',
#                   'type': 'image',
#                   'url': 'images/2021/05/11/multimedia/00xp-vaxsites-dracula/00xp-vaxsites-dracula-watch268.jpg',
#                   'width': 272},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'verticalTwoByThree735',
#                   'height': 1101,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'verticalTwoByThree735',
#                   'subtype': 'verticalTwoByThree735',
#                   'type': 'image',
#                   'url': 'images/2021/05/11/multimedia/00xp-vaxsites-dracula/00xp-vaxsites-dracula-verticalTwoByThree735.jpg',
#                   'width': 735},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mobileMasterAt3x',
#                   'height': 1241,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mobileMasterAt3x',
#                   'subtype': 'mobileMasterAt3x',
#                   'type': 'image',
#                   'url': 'images/2021/05/11/multimedia/00xp-vaxsites-dracula/merlin_187494546_507cbe65-090e-44fa-811a-2371403e33ad-mobileMasterAt3x.jpg',
#                   'width': 1800}],
#   'news_desk': 'Express',
#   'print_page': '4',
#   'print_section': 'A',
#   'pub_date': '2021-05-12T22:02:09+0000',
#   'section_name': 'U.S.',
#   'snippet': 'A beach. A ski resort. Dracula’s house. Some Covid-19 vaccine '
#              'sites are more interesting than others.',
#   'source': 'The New York Times',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/e68f6e90-d3b5-5186-abaa-6c2061dcdbac',
#   'web_url': 'https://www.nytimes.com/2021/05/12/us/covid-vaccine-unusual-location.html',
#   'word_count': 1328}]

# %%
# Print the web_url of each stored article
print("Your Reading List")
for article in articles_list:
    print(article["web_url"])
# Out:
# Your Reading List
# https://www.nytimes.com/interactive/2021/05/20/nyregion/nyvaccine-subway.html
# https://www.nytimes.com/2021/05/14/podcasts/covid-vaccine-hesitancy-tennessee.html
# https://www.nytimes.com/2021/05/20/business/coronavirus-vaccine-mongolia.html
# https://www.nytimes.com/2021/05/24/opinion/vaccine-covid-distribution.html
# https://www.nytimes.com/2021/05/24/opinion/covid-vaccine-hesitancy-prison.html
# https://www.nytimes.com/video/world/europe/100000007779241/who-tedros-vaccine-inequity.html
# https://www.nytimes.com/2021/05/22/world/asia/pakistan-private-vaccines.html
# https://www.nytimes.com/2021/05/24/world/europe/india-uk-variant-vaccine-coronavirus.html
# https://www.nytimes.com/interactive/2021/05/12/health/kids-covid-vaccine.html
# https://www.nytimes.com/2021/05/12/us/covid-vaccine-unusual-location.html
