# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Using MatplotLib to Chart a DataFrame

# %%
# Load in csv
rain_df = pd.read_csv("../Resources/avg_rain_state.csv")
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x axis and tick locations
x_axis = np.arange(len(rain_df))
tick_locations = [value for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, rain_df["Inches"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, rain_df["State"], rotation="45")
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ([<matplotlib.axis.XTick at 0x1a287549b00>,
#   <matplotlib.axis.XTick at 0x1a2861b7cf8>,
#   <matplotlib.axis.XTick at 0x1a28755e198>,
#   <matplotlib.axis.XTick at 0x1a2868d1cf8>,
#   <matplotlib.axis.XTick at 0x1a2868dd208>,
#   <matplotlib.axis.XTick at 0x1a2868dd2b0>,
#   <matplotlib.axis.XTick at 0x1a2868dd908>,
#   <matplotlib.axis.XTick at 0x1a2868dddd8>,
#   <matplotlib.axis.XTick at 0x1a2868e42e8>,
#   <matplotlib.axis.XTick at 0x1a2868e47b8>,
#   <matplotlib.axis.XTick at 0x1a2868e4c88>,
#   <matplotlib.axis.XTick at 0x1a2868ee198>,
#   <matplotlib.axis.XTick at 0x1a2868ee668>,
#   <matplotlib.axis.XTick at 0x1a2868eeb38>,
#   <matplotlib.axis.XTick at 0x1a2868eea90>,
#   <matplotlib.axis.XTick at 0x1a2868e4d68>,
#   <matplotlib.axis.XTick at 0x1a286868320>,
#   <matplotlib.axis.XTick at 0x1a2868f6358>,
#   <matplotlib.axis.XTick at 0x1a2868f6828>,
#   <matplotlib.axis.XTick at 0x1a2868f6cf8>,
#   <matplotlib.axis.XTick at 0x1a2868fe208>,
#   <matplotlib.axis.XTick at 0x1a2868fe6d8>,
#   <matplotlib.axis.XTick at 0x1a2868feba8>,
#   <matplotlib.axis.XTick at 0x1a286906128>,
#   <matplotlib.axis.XTick at 0x1a2868fecf8>,
#   <matplotlib.axis.XTick at 0x1a2868f67f0>,
#   <matplotlib.axis.XTick at 0x1a286906438>,
#   <matplotlib.axis.XTick at 0x1a286906828>,
#   <matplotlib.axis.XTick at 0x1a286906cf8>,
#   <matplotlib.axis.XTick at 0x1a28690f208>,
#   <matplotlib.axis.XTick at 0x1a28690f6d8>,
#   <matplotlib.axis.XTick at 0x1a28690fba8>,
#   <matplotlib.axis.XTick at 0x1a286916128>,
#   <matplotlib.axis.XTick at 0x1a286916588>,
#   <matplotlib.axis.XTick at 0x1a28690f6a0>,
#   <matplotlib.axis.XTick at 0x1a2869062e8>,
#   <matplotlib.axis.XTick at 0x1a286916828>,
#   <matplotlib.axis.XTick at 0x1a286916c88>,
#   <matplotlib.axis.XTick at 0x1a286923198>,
#   <matplotlib.axis.XTick at 0x1a286923668>,
#   <matplotlib.axis.XTick at 0x1a286923b38>,
#   <matplotlib.axis.XTick at 0x1a28692a0b8>,
#   <matplotlib.axis.XTick at 0x1a28692a518>,
#   <matplotlib.axis.XTick at 0x1a2869239b0>,
#   <matplotlib.axis.XTick at 0x1a286916908>,
#   <matplotlib.axis.XTick at 0x1a28692a9e8>,
#   <matplotlib.axis.XTick at 0x1a28692ac88>,
#   <matplotlib.axis.XTick at 0x1a286933198>,
#   <matplotlib.axis.XTick at 0x1a286933668>,
#   <matplotlib.axis.XTick at 0x1a286933b38>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-0.75, len(x_axis))
plt.ylim(0, max(rain_df["Inches"])+10)
# Out:
# (0, 73.7)

# %%
# Set a Title and labels
plt.title("Average Rain per State")
plt.xlabel("State")
plt.ylabel("Average Amount of Rainfall in Inches")
# Out:
# Text(318.69444444444446, 0.5, 'Average Amount of Rainfall in Inches')

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig("../Images/avg_state_rain.png")
plt.show()

# %% [markdown]
# ### Using Pandas to Chart a DataFrame

# %%
# Filter the DataFrame down only to those columns to chart
state_and_inches = rain_df[["State","Inches","Rank"]]

# Set the index to be "State" so they will be used as labels
state_and_inches = state_and_inches.set_index("State")

state_and_inches.head()
# Out:
#             Inches  Rank
# State
# Alabama       58.3     4
# Alaska        22.5    39
# Arizona       13.6    47
# Arkansas      50.6     8
# California    22.2    40

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
state_and_inches.plot(kind="bar", figsize=(20,3))

# Set a title for the chart
plt.title("Average Rain Per State")

plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = rain_df.plot(kind="bar", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(rain_df["State"], rotation=45)

plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="2000">
